# %% [markdown]
# В этой тетрадке мы поговорим о способах собрать свой датасет для исследований: откуда брать данные, как их собирать и как хранить.
#
# Достаточно часто, чтобы собрать данные, нужно что-то выкачать с сайта
#
# Существует несколько библиотек(модулей) для работы с веб-страничками, сегодня мы будем использовать requests для доступа к веб-страничкам и Beautiful Soup для работы с содержимым html-документов

# %%
#импортируем модуль requests
! pip3 install requests
# Out:
# Requirement already satisfied: requests in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (2.25.0)
# WARNING: You are using pip version 20.2.1; however, version 21.0 is available.
# You should consider upgrading via the 'C:\Users\ДНС\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests) (2.10)

# %%
# импортируем модуль beautifulsoup, самая последняя версия - четвертая

! pip3 install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (4.9.3)
# WARNING: You are using pip version 20.2.1; however, version 21.0 is available.
# You should consider upgrading via the 'C:\Users\ДНС\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from beautifulsoup4) (2.1)

# %%
# импортируем модули в тетрадку

import requests as rq

from bs4 import BeautifulSoup

# %% [markdown]
# ## работаем с веб-страничками

# %%
urls = ['https://www.lamoda.ru/p/mp002xw0xkrv/clothes-befree-futbolka/',
        'https://www.lamoda.ru/p/mp002xw041ef/clothes-zarina-futbolka/',
        'https://www.lamoda.ru/p/ka025ewjsjo8/clothes-karllagerfeld-futbolka/',
        'https://www.lamoda.ru/p/ka025ewjsjp4/clothes-karllagerfeld-futbolka/',
        'https://www.lamoda.ru/p/le306ewhhpw1/clothes-levis-futbolka/']

# %%
name_text = {}  
review_text = []
review_name = []
for elem in urls:
    page = rq.get(elem)
    soup = BeautifulSoup(page.text, 'html.parser')
    text = soup.find_all(class_="rev__node-text")
    name= soup.find_all(class_="rev__node-head_author")
    
    for entry in text:
        review_text.append(entry.get_text()) #положили в список отзывов
    
    for entry in name:
        review_name.append(entry.get_text())#положили в список имен
     
    import numpy as np
    for i in np.arange(len(review_name)):
        name_text[review_name[i]] =  review_text[i]
#print(name_text)
with open('review_all_f.txt','w',encoding='utf-8') as out:
    for key,val in name_text.items():
        out.write('{}:{}\n'.format(key,val))

# %%
reviews_all_f = open('review_all_f.txt', encoding='utf-8').read()
#read_reviews = reviews.read() #Пока просто пробую с read,с readlines никак не выходит
print("Тип переменной:",type(reviews_all_f),"\n")
print(reviews_all_f)
# Out:
# Тип переменной: <class 'str'>
#
# ANNA:
#         Отличное качество
#
# вика:
#         Отличная Даша. Рекомендую
#
# Екатерина:
#         Качество на высоту. Хлопок . Очень лёгкая. Сидит очень здорово. Размер в размер
#
# Ксения:
#         👍
#
# Татьяна:
#         Отличная базовая футболка. Достаточно плотная, как и остальные футболки этой фирмы. Цвет не глубокий чёрный.
#
# Юлия:
#         Хорошее качество, соответствует размеру, не приталенная, вырез приличный) хорошая базовая футболка.
#
# Марина:
#         Отличная футболка, как всегда у этого бренда! Ещё и со скидкой! Супер!
#
# Мехтиева Гюльнара:
#         Очень приятная футболка
#
#
# м:
#         отличная футболка под пиджак
#
# Светлана:
#         Рекомендую
#
# Худякова Надежда:
#         Очень понравилась
#
# Алиса:
#         Хорошая, базовая белая футболка, под педжак очень хорошо.
#
# Калита Светлана:
#         Плотная , качество хорошее, маломерит, на XS взяла м
#
# Анастасия:
#         Заказала в подарок. Хорошее качество. Отличный материал.
#
# Юлдуз:
#         Мягкая, но чуть длинные доя роста 152!
# в целом хорошая футболка
#
# 🤗:
#         Хорошая футболка для своей цены, соответствует описанию. На рост 158, ОГ 85, ОТ 65 размер s сидит свободно, но не оверсайз
#
# Ольга:
#         Замечательная футболка. Размер в размер. Качество порадовало.
#
# Мария:
#         Хорошая футболка, цвет действительно не насыщенно чёрный, но не это не портит. После стирки не деформировалась
#
# Aнастасия:
#         Хорошая футболка .приятная к телу . Не просвечивает. Выкупила .
#
# Карасюк Ирина:
#         Отличная хлопковая рубашка, приятная к телу
#
#
# Любовь:
#         Футболка просвечивает, фасон неудачный для девушек с ог 99, от 68. Ткань приятная, но точно будет мяться при первой возможности
#
# Дарья:
#         Крутая качественная футболка. И в пир и в мир, как говорится. Хороший принт, стразы на месте, после стирки не отваливаются.
#
# Надежда:
#         Хорошее качество, понравилась
#
#
# Наталия:
#         Отличная базовая вещь.
#
# Chumak Juliana:
#         Все понравилось 👍
#
# Mariana:
#         Отличная футболка ! Материал хороший , размер соответствует
#
# Люшнина Дарья:
#         всё подошло ,сидит отлично
#
# Людмила:
#         Качество на уровне! Размер в размер. Стразы после стирки не отваливаются
#
# Антонина:
#         Классическая обычная футболка, недостатков пока не нашла)
#
# Алена:
#         Хорошая футболка, спасибо за скидку
#
# Булгакова Светлана:
#         Оч крутые. На рост 160 и вес 45 сели идеально)
#
# Ефимова Алла:
#         Хорошая, еще закажу
#
# Лариса:
#         Хороший трикотаж, мягкий. Размер L идёт на 48. Заказала ещё одну.
#
# Мариета Кобж:
#         Шикарная футболка
#
# елена:
#         На очень покатые плечи, не понравилась
#
# Санникова Наталья:
#         Хорошая обычная белая футболка
#
# Назик:
#         Ткань мягкая и дышащая. Посмотрим, как будет носиться
#
# Виктория:
#         Хорошая футболка, но на деле вырез оказался больше, чем на фото
#
# Ирина:
#         Хорошая базовая футболка, размер в размер
#
# Милла:
#         Хорошая
#
# Галина:
#         Классная футболка. Немного тонковата, но не критично, впринципе не просвечивает, а если надеть бельё телесного цвета-вообще не вижу проблем. Фасон прямой, не длинная, рукава с отворотами.
#
# Елена:
#         Хорошая футболка, идёт в размер. Вырез в самый раз, не слишком глубокий. Футболка прямая (не приталеная)
#
# дарья:
#         Хорошая
#
# Анна:
#         Цвет - выгоревший черный, переходящий в грязный синий. Как будто футболку заносили или оставили под солнцем на долгое время. Логотип пришит неаккуратно, вещь цены заявленной не стоит, по моему мнению.
#
# Полина:
#         Майка отличная!
#
# олеся:
#         По качеству норм. Фото нет
#
#
# Фатимат:
#         Полотые футболки , взяла на размер больше , свободней смотрится и очень удобно 👍🏻
#
# Елизавета:
#         Крутая! Качество хорошее!
#
# Пудерова  Анастасия:
#         Футболка маломерит. По талии идёт свободная. Мне узка по груди, а в талии свободная. По качеству плотный трикотаж. Выкупила, подарю дочке.
#
# Вероника:
#         👍🏻
#
# Александра:
#         Хорошая плотная футболка.
#
# Милена:
#         👍🏻
#
# Михайловна Мария:
#         Отличные плотные футболки. Очень приятная ткань. Крой то что надо.
#
# Ипатова  Светлана:
#         Базовая футболка хоть куда, рекомендую
#
# Соломонова Лариса:
#         Обыкновенная плотная хб футболка. Брала носить дома.
#
# Мирзоева Шохина:
#         Качество хорошее, идет размер в размер и ткань приятная
#
# Гаяне:
#         Хорошее качество
#
# Кулакова Олеся:
#         Футболка отличного качества ,за 419₽ ,хлопок 100%
#
# людмила:
#         Отличная футболка! Качественная! На 42 размер XS хорошо сидит- свободновато, не в обтяг! Спасибо Lamoda
#
# ольга:
#         Мне понравилась
#
# аида тагирова:
#         Плотная хлопковая футболка
#
# снежана:
#         Базовая, рекомендую
#
# Ангелина:
#         Отличная футболка, приятный материал, аккуратные швы, замечательное качество
# Заказывала XS, оказался немножко больше, ближе к S
#
# Анастасии:
#         Очень приятная ткань, не просвечивается. Отличная базовая вещь.  Размеру соответствует.
#
# Залина:
#         Плотная и правильно сшита , не растягивается и не теряет форму после стирки
#
# ксения:
#         Отлично
#
# Шафига:
#         Качество хорошее
#
# анастасия:
#         Отливная базовая футболка
#
# Liubov:
#         Приятная ткань
#
# Гуля:
#         😍
#
# Алина:
#         Качество супер! Идет размер в размер, не в обтяжку. Принт бомбический, стразы все на месте.
#
# Nadya:
#         Отличная! Шелковистый хлопок приятный к телу, не длинная,  в размер!
#
# Яна:
#         Футболка качественная ,стильная. Идёт в размер . Свободная ! Все как и хотела . Заказывала размер м.
#
# яна:
#         Красивая, стильная, удобная. Мне пришла с небольшим браком
#
# Лунгу Марина:
#         Футболка просто супер. Она стоит своих денег.
#
# марина:
#         Отличная,качество супер,немного маломерит
#
# Наталья:
#         Отличная качественная футболка . В размер.
#
# Роман:
#         Все безупречно
#
# Валерия:
#         Купила со скидкой.Хорошая футболка,вроде ничего особенного,но стильно.Я ношу 44р,взяла 42-44 идеально села.
#
# Арина:
#         в восторге от него
#
# наталия:
#         Хорошее качество, размер соответствует. Довольна покупкой
#
# Saule:
#         Тонкий трикотаж, не длинная, идет в размер
#
# Хесон:
#         Good
#
# Цой Николай:
#         Отличная футболка ! Хотя цена немного завышена )
#
# юлия:
#         Качество супер!
#
# Оксана:
#         Качество 👍 отличная базовая вещь.
#
# светлана:
#         Классная футболка.
#
# alina:
#         Хорошая футболка
#
# татьяна:
#         Хорошая футболка, мне понравилась, аккуратно сделана
#
# К Анна:
#         Всё супер. На 46 - М идеально, я часто беру этот бренд, никогда не подводил. Кто хочет оверсайс берите на размер больше будет свободно, но не критично
#
# Мельников  Владислав:
#         Качество на высоте)
#
# виктория:
#         Футболка отличная, Но!!!!! Она была скомкана в пакете!!! Фото приложу! Вот такое «шиворот на выворот» я достала из пакета, на мне видно как она помята-это так упакована 🤷‍♀️ Я понимаю что это интернет магазин, но покупать вещи премиум сегмента, когда она как из одного места -желание отпадает. Магазин , следите за упаковкой! За неё ставлю 2 звёзды .
#
# екатерина:
#         👍👍👍
#
# Александр:
#         Второй половинке очень понравилась, качество на уровне, приятный материал тактильно
#
# Михайлова Лариса:
#         Товар соответствует описанию, качество отличное.
#
# Мажарова Анна:
#         Хорошая, но очень коротенькая. Перезакажу на размер больше.
#
# Каролина:
#         Я купила, но сейчас понимаю, что она вульгарная со стразами, отдам младшей сестре, она у нас в семье такое любит носить, а у меня есть вкус
#
# Иван:
#         Жене понравилась, качество хорошее.
#
# Инна:
#         Футболка замечательная, очень красивая
#
# YULIYA:
#         Классная🔥👍
#
# Покупатель:
#         Отличная
#
# Кристина:
#         Хорошая футболка, села по размеру, была бы еще лучше если лого выполнили в тон, а так для базовой слишком яркий логотип.
#
# Мери:
#         Отличная
#
# Милана:
#         Купила 2 таких футболки! Качество
#  приятно порадовало, очень нравятся! Размеру соответствуют!  Спасибо, Ламода!
#
# Жанна:
#         Очень  понравилась футболка  . Размер  в размер  . Качество  бренда  всегда  радует . Спасибо  ламода  !
#
# Алексей:
#         Качество на высоте!
#
# Yuliya Min:
#         Качество супер
#
# надежда:
#         Отличная футболка, очень качественная, плотная ткань, сшита идеально
#
# Maria:
#         Отличная футболка !
#
# света:
#         Отличная
#
# Катерина:
#         Отличная базовая  футболка.
#
# Жанара:
#         Супер 😍
#
# Ekaterina:
#         Качество у футболки безупречное, плотная ткань. Только футболка короткая и на 48 рос, 46/48 облегает. Надеялась, что будет подлиннее и посвободнее.
#
# Добрина Наталья:
#         На свой 46 размер переходящий порой в 48, Взяла размеры M и L. Выкупила М , села идеально. Футболка очень классная, ещё  закажу только в другом цвете.
#
# Исмаилова  Ольга:
#         Понравилась футболка, брала на размер меньше, т.к не очень люблю свободные модели. Тем, кто любит посвободнее, можно брать размер в размер
#
# Gayane:
#         Мягкая футболка
#
# василиса:
#         Отличное качество
#
# Мотева Ирина:
#         Хорошая футболка чёрного цвета. Идёт в размер.
#
# София:
#         Взяла две. И бедую и чёрную. Не прогадала
#
# Рюмина Елена:
#         Качнство отличное. Полное соответствие ожидаемому
#
#
# ЕвгенияИлюшина:
#         Очень классная) хожу ежедневно
#
# Альбина:
#         Суперские футболки! Купила аж три штуки!
#
# Камила:
#         Отличная футболка
#
# Нина:
#         На мой 44-46 отлично подошёл размер s. Плотненькая, не в обтяжку. Мне нравится футболка, вырез в меру.
#
# Богданов Максим:
#         Нормальная футболка, со скидкой можно брать)
#
# таня:
#         👍🏼
#
# Саттарова Анна:
#         Хлопок 100% Цвет не совсем черный, какой потёртый.
#
# ирина:
#         Отличная футболка, приятная к телу, на свой 46 отлично села 44 размера ,
#
#
# Данила:
#         Супер!
#
# Мирослава:
#         Хорошая хб футболка,размер соответствует
#
# Ainur:
#         Базовая футболка. Немного коротковата, но с высокими джинсами норм. Вырез не слишком глубокий. Материал приятный. Прям как на фото не выглядит, но в целом со скидкой неплохая покупка

# %%
#reviews.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-dd958a885985> in <module>
# ----> 1 reviews.close()
#
# AttributeError: 'list' object has no attribute 'close'

# %%
import itertools
from razdel import sentenize
from razdel import tokenize as razdel_tokenize
from pymorphy2 import MorphAnalyzer
from collections import Counter, defaultdict
import numpy as np
import re
from string import punctuation
from nltk.corpus import stopwords

# %%
stops = set(stopwords.words('russian')) # определили список стоп-слов
morph = MorphAnalyzer()

# %%
def normalize(text):
    tokens = re.findall('[а-яёa-z0-9]+', text.lower())
    normalized_text = [morph.parse(word)[0].normal_form for word \
                                                            in tokens]
    normalized_text = [word for word in normalized_text if word not in stops]
    
    return normalized_text

# %%
def preprocess(text):
    sents = sentenize(text) # разбили текст на предложения
    return [normalize(sent.text) for sent in sents] # возвращаем список нормализованных предложений

# %%
normalize(reviews_all_f)
# Out:
# ['anna',
#  'отличный',
#  'качество',
#  'вика',
#  'отличный',
#  'даша',
#  'рекомендовать',
#  'екатерина',
#  'качество',
#  'высота',
#  'хлопок',
#  'очень',
#  'лёгкий',
#  'сидеть',
#  'очень',
#  'здорово',
#  'размер',
#  'размер',
#  'ксения',
#  'татьяна',
#  'отличный',
#  'базовый',
#  'футболка',
#  'достаточно',
#  'плотный',
#  'остальной',
#  'футболка',
#  'фирма',
#  'цвет',
#  'глубокий',
#  'чёрный',
#  'юлия',
#  'хороший',
#  'качество',
#  'соответствовать',
#  'размер',
#  'приталенный',
#  'вырез',
#  'приличный',
#  'хороший',
#  'базовый',
#  'футболка',
#  'марина',
#  'отличный',
#  'футболка',
#  'это',
#  'бренд',
#  'ещё',
#  'скидка',
#  'супер',
#  'мехтиева',
#  'гюльнар',
#  'очень',
#  'приятный',
#  'футболка',
#  'м',
#  'отличный',
#  'футболка',
#  'пиджак',
#  'светлана',
#  'рекомендовать',
#  'худяков',
#  'надежда',
#  'очень',
#  'понравиться',
#  'алиса',
#  'хороший',
#  'базовый',
#  'белый',
#  'футболка',
#  'педжак',
#  'очень',
#  'калита',
#  'светлана',
#  'плотный',
#  'качество',
#  'хороший',
#  'маломерить',
#  'xs',
#  'взять',
#  'м',
#  'анастасия',
#  'заказать',
#  'подарок',
#  'хороший',
#  'качество',
#  'отличный',
#  'материал',
#  'юлдуз',
#  'мягкий',
#  'длинный',
#  'доить',
#  'рост',
#  '152',
#  'целое',
#  'хороший',
#  'футболка',
#  'хороший',
#  'футболка',
#  'свой',
#  'цена',
#  'соответствовать',
#  'описание',
#  'рост',
#  '158',
#  'ог',
#  '85',
#  '65',
#  'размер',
#  's',
#  'сидеть',
#  'свободно',
#  'оверсайза',
#  'ольга',
#  'замечательный',
#  'футболка',
#  'размер',
#  'размер',
#  'качество',
#  'порадовать',
#  'мария',
#  'хороший',
#  'футболка',
#  'цвет',
#  'действительно',
#  'насыщенно',
#  'чёрный',
#  'это',
#  'портить',
#  'стирка',
#  'деформироваться',
#  'aнастасия',
#  'хороший',
#  'футболка',
#  'приятный',
#  'тело',
#  'просвечивать',
#  'выкупить',
#  'карасюк',
#  'ирина',
#  'отличный',
#  'хлопковый',
#  'рубашка',
#  'приятный',
#  'тело',
#  'любовь',
#  'футболка',
#  'просвечивать',
#  'фасон',
#  'неудачный',
#  'девушка',
#  'ог',
#  '99',
#  '68',
#  'ткань',
#  'приятный',
#  'точно',
#  'мяться',
#  'первый',
#  'возможность',
#  'дарья',
#  'крутой',
#  'качественный',
#  'футболка',
#  'пир',
#  'мир',
#  'говориться',
#  'хороший',
#  'принт',
#  'страз',
#  'место',
#  'стирка',
#  'отваливаться',
#  'надежда',
#  'хороший',
#  'качество',
#  'понравиться',
#  'наталия',
#  'отличный',
#  'базовый',
#  'вещь',
#  'chumak',
#  'juliana',
#  'всё',
#  'понравиться',
#  'mariana',
#  'отличный',
#  'футболка',
#  'материал',
#  'хороший',
#  'размер',
#  'соответствовать',
#  'люшнина',
#  'дарья',
#  'всё',
#  'подойти',
#  'сидеть',
#  'отлично',
#  'людмила',
#  'качество',
#  'уровень',
#  'размер',
#  'размер',
#  'страз',
#  'стирка',
#  'отваливаться',
#  'антонин',
#  'классический',
#  'обычный',
#  'футболка',
#  'недостаток',
#  'пока',
#  'найти',
#  'ален',
#  'хороший',
#  'футболка',
#  'спасибо',
#  'скидка',
#  'булгаков',
#  'светлана',
#  'оч',
#  'крутой',
#  'рост',
#  '160',
#  'вес',
#  '45',
#  'сель',
#  'идеально',
#  'ефимов',
#  'алла',
#  'хороший',
#  'ещё',
#  'заказать',
#  'лариса',
#  'хороший',
#  'трикотаж',
#  'мягкий',
#  'размер',
#  'l',
#  'идти',
#  '48',
#  'заказать',
#  'ещё',
#  'мариета',
#  'кобжа',
#  'шикарный',
#  'футболка',
#  'елена',
#  'очень',
#  'покатый',
#  'плечо',
#  'понравиться',
#  'санников',
#  'наталья',
#  'хороший',
#  'обычный',
#  'белый',
#  'футболка',
#  'назик',
#  'ткань',
#  'мягкий',
#  'дышать',
#  'посмотреть',
#  'носиться',
#  'виктория',
#  'хороший',
#  'футболка',
#  'дело',
#  'вырез',
#  'оказаться',
#  'большой',
#  'фото',
#  'ирина',
#  'хороший',
#  'базовый',
#  'футболка',
#  'размер',
#  'размер',
#  'милла',
#  'хороший',
#  'галина',
#  'классный',
#  'футболка',
#  'немного',
#  'тонковатый',
#  'критично',
#  'впринцип',
#  'просвечивать',
#  'надеть',
#  'бельё',
#  'телесный',
#  'цвет',
#  'вообще',
#  'видеть',
#  'проблема',
#  'фасон',
#  'прямой',
#  'длинный',
#  'рукав',
#  'отворот',
#  'елена',
#  'хороший',
#  'футболка',
#  'идти',
#  'размер',
#  'вырез',
#  'самый',
#  'слишком',
#  'глубокий',
#  'футболка',
#  'прямой',
#  'приталёный',
#  'дарья',
#  'хороший',
#  'анна',
#  'цвет',
#  'выгореть',
#  'чёрный',
#  'переходящий',
#  'грязный',
#  'синий',
#  'футболка',
#  'заносить',
#  'оставить',
#  'солнце',
#  'долгий',
#  'время',
#  'логотип',
#  'пришить',
#  'неаккуратно',
#  'вещь',
#  'цена',
#  'заявить',
#  'стоить',
#  'мнение',
#  'полина',
#  'майк',
#  'отличный',
#  'олеся',
#  'качество',
#  'норма',
#  'фото',
#  'фатимат',
#  'полоть',
#  'футболка',
#  'взять',
#  'размер',
#  'большой',
#  'свободный',
#  'смотреться',
#  'очень',
#  'удобно',
#  'елизавета',
#  'крутой',
#  'качество',
#  'хороший',
#  'пудеров',
#  'анастасия',
#  'футболка',
#  'маломерить',
#  'талия',
#  'идти',
#  'свободный',
#  'узкий',
#  'грудь',
#  'талия',
#  'свободный',
#  'качество',
#  'плотный',
#  'трикотаж',
#  'выкупить',
#  'подарить',
#  'дочка',
#  'вероника',
#  'александр',
#  'хороший',
#  'плотный',
#  'футболка',
#  'милена',
#  'михаилович',
#  'мария',
#  'отличный',
#  'плотный',
#  'футболка',
#  'очень',
#  'приятный',
#  'ткань',
#  'крой',
#  'ипатово',
#  'светлана',
#  'базовый',
#  'футболка',
#  'рекомендовать',
#  'соломонов',
#  'лариса',
#  'обыкновенный',
#  'плотный',
#  'хб',
#  'футболка',
#  'брать',
#  'носить',
#  'дом',
#  'мирзоев',
#  'шохин',
#  'качество',
#  'хороший',
#  'идти',
#  'размер',
#  'размер',
#  'ткань',
#  'приятный',
#  'гаяне',
#  'хороший',
#  'качество',
#  'кулаковый',
#  'олеся',
#  'футболка',
#  'отличный',
#  'качество',
#  '419',
#  'хлопок',
#  '100',
#  'людмила',
#  'отличный',
#  'футболка',
#  'качественный',
#  '42',
#  'размер',
#  'xs',
#  'сидеть',
#  'свободноватый',
#  'обтяга',
#  'спасибо',
#  'lamoda',
#  'ольга',
#  'понравиться',
#  'аида',
#  'тагиров',
#  'плотный',
#  'хлопковый',
#  'футболка',
#  'снежана',
#  'базовый',
#  'рекомендовать',
#  'ангелина',
#  'отличный',
#  'футболка',
#  'приятный',
#  'материал',
#  'аккуратный',
#  'шов',
#  'замечательный',
#  'качество',
#  'заказывать',
#  'xs',
#  'оказаться',
#  'немножко',
#  'большой',
#  'близкий',
#  's',
#  'анастасия',
#  'очень',
#  'приятный',
#  'ткань',
#  'просвечиваться',
#  'отличный',
#  'базовый',
#  'вещь',
#  'размер',
#  'соответствовать',
#  'залина',
#  'плотный',
#  'правильно',
#  'сшить',
#  'растягиваться',
#  'терять',
#  'форма',
#  'стирка',
#  'ксения',
#  'отлично',
#  'шафиг',
#  'качество',
#  'хороший',
#  'анастасия',
#  'отливный',
#  'базовый',
#  'футболка',
#  'liubov',
#  'приятный',
#  'ткань',
#  'гуля',
#  'алина',
#  'качество',
#  'супер',
#  'идти',
#  'размер',
#  'размер',
#  'обтяжка',
#  'принт',
#  'бомбический',
#  'страз',
#  'всё',
#  'место',
#  'nadya',
#  'отличный',
#  'шелковистый',
#  'хлопок',
#  'приятный',
#  'тело',
#  'длинный',
#  'размер',
#  'ян',
#  'футболка',
#  'качественный',
#  'стильный',
#  'идти',
#  'размер',
#  'свободный',
#  'всё',
#  'хотеть',
#  'заказывать',
#  'размер',
#  'м',
#  'ян',
#  'красивый',
#  'стильный',
#  'удобный',
#  'прийти',
#  'небольшой',
#  'брак',
#  'лунг',
#  'марина',
#  'футболка',
#  'просто',
#  'супер',
#  'стоить',
#  'свой',
#  'деньга',
#  'марина',
#  'отличный',
#  'качество',
#  'супер',
#  'немного',
#  'маломерить',
#  'наталья',
#  'отличный',
#  'качественный',
#  'футболка',
#  'размер',
#  'роман',
#  'всё',
#  'безупречно',
#  'валерий',
#  'купить',
#  'скидка',
#  'хороший',
#  'футболка',
#  'вроде',
#  'особенный',
#  'стильно',
#  'носить',
#  '44р',
#  'взять',
#  '42',
#  '44',
#  'идеально',
#  'село',
#  'арин',
#  'восторг',
#  'наталия',
#  'хороший',
#  'качество',
#  'размер',
#  'соответствовать',
#  'довольный',
#  'покупка',
#  'saule',
#  'тонкий',
#  'трикотаж',
#  'длинный',
#  'идти',
#  'размер',
#  'хесон',
#  'good',
#  'цой',
#  'николай',
#  'отличный',
#  'футболка',
#  'хотя',
#  'цена',
#  'немного',
#  'завысить',
#  'юлия',
#  'качество',
#  'супер',
#  'оксана',
#  'качество',
#  'отличный',
#  'базовый',
#  'вещь',
#  'светлана',
#  'классный',
#  'футболка',
#  'alina',
#  'хороший',
#  'футболка',
#  'татьяна',
#  'хороший',
#  'футболка',
#  'понравиться',
#  'аккуратно',
#  'сделать',
#  'анна',
#  'всё',
#  'супер',
#  '46',
#  'м',
#  'идеально',
#  'часто',
#  'брать',
#  'бренд',
#  'подводить',
#  'хотеть',
#  'оверсайса',
#  'брать',
#  'размер',
#  'большой',
#  'свободно',
#  'критично',
#  'мельников',
#  'владислав',
#  'качество',
#  'высота',
#  'виктория',
#  'футболка',
#  'отличный',
#  'скомкать',
#  'пакет',
#  'фото',
#  'приложить',
#  'шиворот',
#  'выворот',
#  'достать',
#  'пакет',
#  'видно',
#  'помятый',
#  'это',
#  'упаковать',
#  'понимать',
#  'это',
#  'интернет',
#  'магазин',
#  'покупать',
#  'вещь',
#  'премиум',
#  'сегмент',
#  'место',
#  'желание',
#  'отпадать',
#  'магазин',
#  'следить',
#  'упаковка',
#  'ставить',
#  '2',
#  'звезда',
#  'екатерина',
#  'александр',
#  'второй',
#  'половинка',
#  'очень',
#  'понравиться',
#  'качество',
#  'уровень',
#  'приятный',
#  'материал',
#  'тактильно',
#  'михайлов',
#  'лариса',
#  'товар',
#  'соответствовать',
#  'описание',
#  'качество',
#  'отличный',
#  'мажаров',
#  'анна',
#  'хороший',
#  'очень',
#  'коротенький',
#  'перезаказать',
#  'размер',
#  'большой',
#  'каролина',
#  'купить',
#  'понимать',
#  'вульгарный',
#  'страз',
#  'отдать',
#  'младший',
#  'сестра',
#  'семья',
#  'любить',
#  'носить',
#  'вкус',
#  'иван',
#  'жена',
#  'понравиться',
#  'качество',
#  'хороший',
#  'инна',
#  'футболка',
#  'замечательный',
#  'очень',
#  'красивый',
#  'yuliya',
#  'классный',
#  'покупатель',
#  'отличный',
#  'кристина',
#  'хороший',
#  'футболка',
#  'село',
#  'размер',
#  'ещё',
#  'хороший',
#  'лого',
#  'выполнить',
#  'тон',
#  'базовый',
#  'слишком',
#  'яркий',
#  'логотип',
#  'мери',
#  'отличный',
#  'милан',
#  'купить',
#  '2',
#  'футболка',
#  'качество',
#  'приятно',
#  'порадовать',
#  'очень',
#  'нравиться',
#  'размер',
#  'соответствовать',
#  'спасибо',
#  'ламода',
#  'жанна',
#  'очень',
#  'понравиться',
#  'футболка',
#  'размер',
#  'размер',
#  'качество',
#  'бренд',
#  'радовать',
#  'спасибо',
#  'ламода',
#  'алексей',
#  'качество',
#  'высота',
#  'yuliya',
#  'min',
#  'качество',
#  'супер',
#  'надежда',
#  'отличный',
#  'футболка',
#  'очень',
#  'качественный',
#  'плотный',
#  'ткань',
#  'сшить',
#  'идеально',
#  'maria',
#  'отличный',
#  'футболка',
#  'свет',
#  'отличный',
#  'катерина',
#  'отличный',
#  'базовый',
#  'футболка',
#  'жанар',
#  'супер',
#  'ekaterina',
#  'качество',
#  'футболка',
#  'безупречный',
#  'плотный',
#  'ткань',
#  'футболка',
#  'короткий',
#  '48',
#  'расти',
#  '46',
#  '48',
#  'облегать',
#  'надеяться',
#  'подлинный',
#  'свободный',
#  'добрина',
#  'наталья',
#  'свой',
#  '46',
#  'размер',
#  'переходящий',
#  'порой',
#  '48',
#  'взять',
#  'размер',
#  'm',
#  'l',
#  'выкупить',
#  'м',
#  'село',
#  'идеально',
#  'футболка',
#  'очень',
#  'классный',
#  'ещё',
#  'заказать',
#  'друг',
#  'цвет',
#  'исмаиловый',
#  'ольга',
#  'понравиться',
#  'футболка',
#  'брать',
#  'размер',
#  'маленький',
#  'очень',
#  'любить',
#  'свободный',
#  'модель',
#  'любить',
#  'свободный',
#  'брать',
#  'размер',
#  'размер',
#  'gayane',
#  'мягкий',
#  'футболка',
#  'василиса',
#  'отличный',
#  'качество',
#  'мотева',
#  'ирина',
#  'хороший',
#  'футболка',
#  'чёрный',
#  'цвет',
#  'идти',
#  'размер',
#  'софия',
#  'взять',
#  'бедовать',
#  'чёрный',
#  'прогадать',
#  'рюмин',
#  'елена',
#  'качнство',
#  'отличный',
#  'полный',
#  'соответствие',
#  'ожидать',
#  'евгенияилюшин',
#  'очень',
#  'классный',
#  'ходить',
#  'ежедневно',
#  'альбина',
#  'суперский',
#  'футболка',
#  'купить',
#  'аж',
#  'штука',
#  'камил',
#  'отличный',
#  'футболка',
#  'нина',
#  '44',
#  '46',
#  'отлично',
#  'подойти',
#  'размер',
#  's',
#  'плотненький',
#  'обтяжка',
#  'нравиться',
#  'футболка',
#  'вырез',
#  'мера',
#  'богданов',
#  'максим',
#  'нормальный',
#  'футболка',
#  'скидка',
#  'брать',
#  'таня',
#  'саттаров',
#  'анна',
#  'хлопок',
#  '100',
#  'цвет',
#  'чёрный',
#  'потёртый',
#  'ирина',
#  'отличный',
#  'футболка',
#  'приятный',
#  'тело',
#  'свой',
#  '46',
#  'отлично',
#  'село',
#  '44',
#  'размер',
#  'данил',
#  'супер',
#  'мирослав',
#  'хороший',
#  'хб',
#  'футболка',
#  'размер',
#  'соответствовать',
#  'ainur',
#  'базовый',
#  'футболка',
#  'немного',
#  'коротковатый',
#  'высокий',
#  'джинсы',
#  'норма',
#  'вырез',
#  'слишком',
#  'глубокий',
#  'материал',
#  'приятный',
#  'прям',
#  'фото',
#  'выглядеть',
#  'целое',
#  'скидка',
#  'неплохой',
#  'покупка']

# %%
reviews_all_f = preprocess(reviews_all_f)

# %%
print(len(reviews_all_f))

display(reviews_all_f[10:20])
# Out:
# 126
# [['ещё', 'скидка'],
#  ['супер'],
#  ['мехтиева',
#   'гюльнар',
#   'очень',
#   'приятный',
#   'футболка',
#   'м',
#   'отличный',
#   'футболка',
#   'пиджак',
#   'светлана',
#   'рекомендовать',
#   'худяков',
#   'надежда',
#   'очень',
#   'понравиться',
#   'алиса',
#   'хороший',
#   'базовый',
#   'белый',
#   'футболка',
#   'педжак',
#   'очень'],
#  ['калита',
#   'светлана',
#   'плотный',
#   'качество',
#   'хороший',
#   'маломерить',
#   'xs',
#   'взять',
#   'м',
#   'анастасия',
#   'заказать',
#   'подарок'],
#  ['хороший', 'качество'],
#  ['отличный', 'материал'],
#  ['юлдуз',
#   'мягкий',
#   'длинный',
#   'доить',
#   'рост',
#   '152',
#   'целое',
#   'хороший',
#   'футболка',
#   'хороший',
#   'футболка',
#   'свой',
#   'цена',
#   'соответствовать',
#   'описание'],
#  ['рост',
#   '158',
#   'ог',
#   '85',
#   '65',
#   'размер',
#   's',
#   'сидеть',
#   'свободно',
#   'оверсайза',
#   'ольга',
#   'замечательный',
#   'футболка'],
#  ['размер', 'размер'],
#  ['качество', 'порадовать']]

# %%
def ngrammer(tokens, stops, n=2):
    ngrams = []
    tokens = [token for token in tokens if token not in stops] # добавляем все слова текста кроме стоп-слов
    for i in range(0,len(tokens)-n+1):
        # для каждого элемента списка, включительно, минус окно:
        ngrams.append(tuple(tokens[i:i+n])) # присоединяем элемент и все соседние в зависимости от размера окна
    return ngrams # возвращаем список таких кортежей

# %%
word_counter = Counter()

for sent in reviews_all_f:
    word_counter.update(ngrammer(sent, n=2, stops=stops))

# %%
word_counter.most_common(20)
# Out:
# [(('хороший', 'футболка'), 12),
#  (('отличный', 'футболка'), 10),
#  (('размер', 'размер'), 8),
#  (('базовый', 'футболка'), 7),
#  (('идти', 'размер'), 6),
#  (('отличный', 'базовый'), 5),
#  (('хороший', 'качество'), 5),
#  (('качество', 'хороший'), 5),
#  (('размер', 'соответствовать'), 5),
#  (('отличный', 'качество'), 4),
#  (('приятный', 'тело'), 4),
#  (('качество', 'супер'), 4),
#  (('качество', 'высота'), 3),
#  (('хороший', 'базовый'), 3),
#  (('очень', 'приятный'), 3),
#  (('очень', 'понравиться'), 3),
#  (('футболка', 'приятный'), 3),
#  (('базовый', 'вещь'), 3),
#  (('размер', 'большой'), 3),
#  (('приятный', 'ткань'), 3)]
